# %%
import pandas as pd

from acquirer import *

# %%
df = pd.read_csv('Enamine50k_rdkit2d.csv')
df = df.iloc[:,1:]

# %%
random_search = RandomSearch(subset_size=500)
objective_function = 'd'

# %%
random_search.select_top_element(df,objective_function)
# Out:
#            name                                             smiles  score  \
# 24326  lig40629  O=C(c1ccc2c(c1)[nH]c(=O)n2CC1CC1)N1CCc2nn[nH]c2C1   -8.6
# 688    lig27079       CC[C@H](NC(=O)c1ccc(S(=O)(=O)NC)nc1)c1ccccn1   -7.1
# 41236  lig41652         Cn1nc(C(=O)N2CCCC3(C=Cc4ccccc4O3)C2)ccc1=O   -8.6
# 36732   lig5957     Cc1nn(Cc2ccccc2)c(C)c1C(=O)N[C@H](C)C(=O)N(C)C   -6.9
# 49498  lig25670                       Cc1cc[nH]c1C(=O)N1CCOC(CF)C1   -6.1
# ...         ...                                                ...    ...
# 42744  lig44417  O=C(c1cnn2c1N[C@@H](C1CC1)C[C@H]2C(F)F)N1CCC[C...   -6.9
# 37083  lig34716        CC(C)(C)c1nccc(NC(=O)CC(n2cccn2)C(F)(F)F)n1   -6.8
# 11426  lig12771               OCCOc1cncc(N2CCCC2c2ccc3c(c2)OCO3)n1   -8.7
# 27040  lig43621             CC1CCc2[nH]c3ccc(C(=O)NCCN(C)C)cc3c2C1   -7.6
# 15612   lig4482             CCC1CN(C(=O)Cn2cnc3ccccc3c2=O)CC1N(C)C   -7.0
#
#        BalabanJ      BertzCT       Chi0      Chi0n      Chi0v       Chi1  \
# ...
